# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df=pd.read_csv("custchurn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1209  8268-YDIXR    Male              0     Yes         No      56
# 4338  9708-HPXWZ    Male              1      No         No       5
# 2611  5976-JCJRH    Male              0     Yes         No      10
# 897   0678-RLHVP  Female              0      No         No      53
# 6598  6169-PGNCD  Female              0      No         No      57
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1209          Yes               Yes     Fiber optic            Yes  ...
# 4338           No  No phone service             DSL             No  ...
# 2611          Yes                No     Fiber optic             No  ...
# 897           Yes               Yes     Fiber optic             No  ...
# 6598          Yes                No             DSL            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#remove customerID as it is useless for us here

# %%
df.drop('customerID', axis='columns', inplace=True)

# %%
df.sample(5)
# Out:
#      gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4100   Male              0     Yes         No      50          Yes
# 1099   Male              0     Yes        Yes       5          Yes
# 1      Male              0      No         No      34          Yes
# 4526   Male              0      No         No      13          Yes
# 6640   Male              0     Yes        Yes      28           No
#
#          MultipleLines InternetService       OnlineSecurity  \
# 4100                No              No  No internet service
# 1099               Yes             DSL                   No
# 1                   No             DSL                  Yes
# 4526                No     Fiber optic                  Yes
# 6640  No phone service             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 4100  No internet service  No internet service  No internet service
# ...

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#convert TotalCharges to numeric, coerce will put na where it cannot convert, example where there is no value or space
pd.to_numeric(df.TotalCharges, errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges, errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df.iloc[488] #intergerLocation
# Out:
# gender                                 Female
# SeniorCitizen                               0
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# Name: 488, dtype: object

# %%
df.iloc[3].TotalCharges
# Out:
# '1840.75'

# %%
df1=df[df.TotalCharges!=' ']

# %%
df1.shape
# Out:
# (7032, 20)

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# <ipython-input-21-b67e0c3d31a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
tenure_no=df1[df1.Churn=='No'].tenure #not leaving
tenure_yes=df1[df1.Churn=='Yes'].tenure #leaving

# %%
plt.hist([tenure_yes, tenure_no], color=['pink', 'green'], label=['Churn=Yes', 'Churn=No'])
plt.legend()
plt.xlabel('tenure')
plt.ylabel('no.of customers')
plt.title('customer churn prediction visualization')
# Out:
# Text(0.5, 1.0, 'customer churn prediction visualization')

# %%
month_no=df1[df1.Churn=='No'].MonthlyCharges #not leaving
month_yes=df1[df1.Churn=='Yes'].MonthlyCharges #leaving

# %%
plt.hist([month_yes, month_no], color=['pink', 'green'], label=['Churn=Yes', 'Churn=No'])
plt.legend()
plt.xlabel('MonthlyCharges')
plt.ylabel('no.of customers')
plt.title('customer churn prediction visualization')
# Out:
# Text(0.5, 1.0, 'customer churn prediction visualization')

# %%
def unique_col_values(df):
    for column in df:
        if df[column].dtypes=='object':
            print(f'{column}: {df[column].unique()}')

# %%
unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df1.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1585    Male              0     Yes         No      42          Yes
# 23    Female              0     Yes         No      58          Yes
# 1055  Female              0      No         No      36          Yes
# 4918    Male              0     Yes        Yes      51          Yes
# 164   Female              0     Yes        Yes      11          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 1585           Yes             DSL                  Yes                   No
# 23             Yes             DSL                   No                  Yes
# 1055            No              No  No internet service  No internet service
# 4918            No              No  No internet service  No internet service
# 164             No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df1.replace('No phone service', 'No', inplace = True)
df1.replace('No internet service', 'No', inplace = True)
# Out:
# <ipython-input-30-87a5fd6a8a8e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace = True)
# <ipython-input-30-87a5fd6a8a8e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace = True)

# %%
unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
yes_no_col=['Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 
            'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']
for col in yes_no_col:
    df1[col].replace({'Yes':1, 'No':0}, inplace=True)
# Out:
# <ipython-input-32-4ec380e3d41f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes':1, 'No':0}, inplace=True)

# %%
for column in df1:
        print(f'{column}: {df1[column].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1, 'Male':0}, inplace=True)
# Out:
# <ipython-input-34-42199c906633>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1, 'Male':0}, inplace=True)

# %%
for column in df1:
        print(f'{column}: {df1[column].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
pd.get_dummies(df1.InternetService)
# Out:
#       DSL  Fiber optic  No
# 0       1            0   0
# 1       1            0   0
# 2       1            0   0
# 3       1            0   0
# 4       0            1   0
# ...   ...          ...  ..
# 7038    1            0   0
# 7039    0            1   0
# 7040    1            0   0
# 7041    0            1   0
# 7042    0            1   0
#
# [7032 rows x 3 columns]

# %%
df2=pd.get_dummies(data=df1, columns=['InternetService', 'Contract', 'PaymentMethod'])

# %%
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
to_scale=['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
df2[to_scale]=scaler.fit_transform(df2[to_scale])

# %%
df2
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0          1              0        1           0  0.000000             0
# 1          0              0        0           0  0.464789             1
# 2          0              0        0           0  0.014085             1
# 3          0              0        0           0  0.619718             0
# 4          1              0        0           0  0.014085             1
# ...      ...            ...      ...         ...       ...           ...
# 7038       0              0        1           1  0.323944             1
# 7039       1              0        1           1  1.000000             1
# 7040       1              0        1           1  0.140845             0
# 7041       0              1        1           0  0.042254             1
# 7042       0              0        0           0  0.915493             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
X=df2.drop('Churn', axis='columns')
y=df2['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2, random_state=5)

# %%
X_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# ...      ...            ...      ...         ...       ...           ...
# 3051       1              0        1           1  0.985915             1
# 1730       0              0        0           0  0.000000             1
# 4086       1              0        1           0  1.000000             1
# 2259       1              0        0           0  0.098592             1
# 2920       1              0        1           0  1.000000             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model=keras.Sequential([
    keras.layers.Dense(20, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15,  activation='relu'),
    keras.layers.Dense(1,  activation='sigmoid'),
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.5120 - accuracy: 0.7481
# Epoch 2/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4311 - accuracy: 0.7927
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4211 - accuracy: 0.7973
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.8000
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.8007
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4130 - accuracy: 0.8021
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4118 - accuracy: 0.8009
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4095 - accuracy: 0.8052
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8073
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4748 - accuracy: 0.7740
# [0.4748241901397705, 0.7739872336387634]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 1ms/step
# array([[0.12743883],
#        [0.55667704],
#        [0.00988842],
#        [0.8461327 ],
#        [0.47673136]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:5]
# Out:
# [0, 1, 0, 1, 0]

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       999
#            1       0.64      0.50      0.56       408
#
#     accuracy                           0.77      1407
#    macro avg       0.73      0.69      0.70      1407
# weighted avg       0.76      0.77      0.76      1407

# %%
import seaborn as sn
conf_matrix=tf.math.confusion_matrix(labels=y_test, predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(conf_matrix, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
